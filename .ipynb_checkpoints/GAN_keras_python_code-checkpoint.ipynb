# %%
from keras import models
from keras import layers
from keras.optimizers import SGD
from keras.datasets import mnist
import numpy
from PIL import Image
import matplotlib.pyplot as plt
import cv2

# %% [markdown]
# # Generator Model

# %%
model1 = models.Sequential()
model1.add(layers.Dense(input_dim=100,output_dim=1024,activation="tanh"))
model1.add(layers.Dense(128*7*7,activation="tanh"))
model1.add(layers.BatchNormalization())
model1.add(layers.Activation("tanh"))
model1.add(layers.Reshape((7,7,128),input_shape=(128*7*7,)))
model1.add(layers.UpSampling2D(size=(2,2)))
model1.add(layers.Conv2D(64,(5,5),padding='same',activation='tanh'))
model1.add(layers.UpSampling2D(size=(2,2)))
model1.add(layers.Conv2D(1,(5,5),padding='same',activation='tanh'))
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(input_dim=100, activation="tanh", units=1024)`

# %%
help("keras.layers.Conv2D")
# Out:
# Help on class Conv2D in keras.layers:
#
# keras.layers.Conv2D = class Conv2D(_Conv)
#  |  2D convolution layer (e.g. spatial convolution over images).
#  |
#  |  This layer creates a convolution kernel that is convolved
#  |  with the layer input to produce a tensor of
#  |  outputs. If `use_bias` is True,
#  |  a bias vector is created and added to the outputs. Finally, if
#  |  `activation` is not `None`, it is applied to the outputs as well.
#  |
#  |  When using this layer as the first layer in a model,
#  |  provide the keyword argument `input_shape`
#  |  (tuple of integers, does not include the sample axis),
#  |  e.g. `input_shape=(128, 128, 3)` for 128x128 RGB pictures
#  |  in `data_format="channels_last"`.
#  |
#  |  # Arguments
#  |      filters: Integer, the dimensionality of the output space
#  |          (i.e. the number of output filters in the convolution).
#  |      kernel_size: An integer or tuple/list of 2 integers, specifying the
#  |          height and width of the 2D convolution window.
#  |          Can be a single integer to specify the same value for
#  |          all spatial dimensions.
#  |      strides: An integer or tuple/list of 2 integers,
#  |          specifying the strides of the convolution
#  |          along the height and width.
#  |          Can be a single integer to specify the same value for
#  |          all spatial dimensions.
#  |          Specifying any stride value != 1 is incompatible with specifying
#  |          any `dilation_rate` value != 1.
#  |      padding: one of `"valid"` or `"same"` (case-insensitive).
#  |          Note that `"same"` is slightly inconsistent across backends with
#  |          `strides` != 1, as described
#  |          [here](https://github.com/keras-team/keras/pull/9473#issuecomment-372166860)
#  |      data_format: A string,
#  |          one of `"channels_last"` or `"channels_first"`.
#  |          The ordering of the dimensions in the inputs.
#  |          `"channels_last"` corresponds to inputs with shape
#  |          `(batch, height, width, channels)` while `"channels_first"`
#  |          corresponds to inputs with shape
#  |          `(batch, channels, height, width)`.
#  |          It defaults to the `image_data_format` value found in your
#  |          Keras config file at `~/.keras/keras.json`.
#  |          If you never set it, then it will be "channels_last".
#  |      dilation_rate: an integer or tuple/list of 2 integers, specifying
#  |          the dilation rate to use for dilated convolution.
#  |          Can be a single integer to specify the same value for
#  |          all spatial dimensions.
#  |          Currently, specifying any `dilation_rate` value != 1 is
#  |          incompatible with specifying any stride value != 1.
#  |      activation: Activation function to use
#  |          (see [activations](../activations.md)).
#  |          If you don't specify anything, no activation is applied
#  |          (ie. "linear" activation: `a(x) = x`).
#  |      use_bias: Boolean, whether the layer uses a bias vector.
#  |      kernel_initializer: Initializer for the `kernel` weights matrix
#  |          (see [initializers](../initializers.md)).
#  |      bias_initializer: Initializer for the bias vector
#  |          (see [initializers](../initializers.md)).
#  |      kernel_regularizer: Regularizer function applied to
#  |          the `kernel` weights matrix
#  |          (see [regularizer](../regularizers.md)).
#  |      bias_regularizer: Regularizer function applied to the bias vector
#  |          (see [regularizer](../regularizers.md)).
#  |      activity_regularizer: Regularizer function applied to
#  |          the output of the layer (its "activation").
#  |          (see [regularizer](../regularizers.md)).
#  |      kernel_constraint: Constraint function applied to the kernel matrix
#  |          (see [constraints](../constraints.md)).
#  |      bias_constraint: Constraint function applied to the bias vector
#  |          (see [constraints](../constraints.md)).
#  |
#  |  # Input shape
#  |      4D tensor with shape:
#  |      `(batch, channels, rows, cols)`
#  |      if `data_format` is `"channels_first"`
#  |      or 4D tensor with shape:
#  |      `(batch, rows, cols, channels)`
#  |      if `data_format` is `"channels_last"`.
#  |
#  |  # Output shape
#  |      4D tensor with shape:
#  |      `(batch, filters, new_rows, new_cols)`
#  |      if `data_format` is `"channels_first"`
#  |      or 4D tensor with shape:
#  |      `(batch, new_rows, new_cols, filters)`
#  |      if `data_format` is `"channels_last"`.
#  |      `rows` and `cols` values might have changed due to padding.
#  |
#  |  Method resolution order:
#  |      Conv2D
#  |      _Conv
#  |      keras.engine.base_layer.Layer
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, filters, kernel_size, strides=(1, 1), padding='valid', data_format=None, dilation_rate=(1, 1), activation=None, use_bias=True, kernel_initializer='glorot_uniform', bias_initializer='zeros', kernel_regularizer=None, bias_regularizer=None, activity_regularizer=None, kernel_constraint=None, bias_constraint=None, **kwargs)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  get_config(self)
#  |      Returns the config of the layer.
#  |
#  |      A layer config is a Python dictionary (serializable)
#  |      containing the configuration of a layer.
#  |      The same layer can be reinstantiated later
#  |      (without its trained weights) from this configuration.
#  |
#  |      The config of a layer does not include connectivity
#  |      information, nor the layer class name. These are handled
#  |      by `Network` (one layer of abstraction above).
#  |
#  |      # Returns
#  |          Python dictionary.
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from _Conv:
#  |
#  |  build(self, input_shape)
#  |      Creates the layer weights.
#  |
#  |      Must be implemented on all layers that have weights.
#  |
#  |      # Arguments
#  |          input_shape: Keras tensor (future input to layer)
#  |              or list/tuple of Keras tensors to reference
#  |              for weight shape computations.
#  |
#  |  call(self, inputs)
#  |      This is where the layer's logic lives.
#  |
#  |      # Arguments
#  |          inputs: Input tensor, or list/tuple of input tensors.
#  |          **kwargs: Additional keyword arguments.
#  |
#  |      # Returns
#  |          A tensor or list/tuple of tensors.
#  |
#  |  compute_output_shape(self, input_shape)
#  |      Computes the output shape of the layer.
#  |
#  |      Assumes that the layer will be built
#  |      to match that input shape provided.
#  |
#  |      # Arguments
#  |          input_shape: Shape tuple (tuple of integers)
#  |              or list of shape tuples (one per output tensor of the layer).
#  |              Shape tuples can include None for free dimensions,
#  |              instead of an integer.
#  |
#  |      # Returns
#  |          An input shape tuple.
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from keras.engine.base_layer.Layer:
#  |
#  |  __call__(self, inputs, **kwargs)
#  |      Wrapper around self.call(), for handling internal references.
#  |
#  |      If a Keras tensor is passed:
#  |          - We call self._add_inbound_node().
#  |          - If necessary, we `build` the layer to match
#  |              the _keras_shape of the input(s).
#  |          - We update the _keras_shape of every input tensor with
#  |              its new shape (obtained via self.compute_output_shape).
#  |              This is done as part of _add_inbound_node().
#  |          - We update the _keras_history of the output tensor(s)
#  |              with the current layer.
#  |              This is done as part of _add_inbound_node().
#  |
#  |      # Arguments
#  |          inputs: Can be a tensor or list/tuple of tensors.
#  |          **kwargs: Additional keyword arguments to be passed to `call()`.
#  |
#  |      # Returns
#  |          Output of the layer's `call` method.
#  |
#  |      # Raises
#  |          ValueError: in case the layer is missing shape information
#  |              for its `build` call.
#  |
#  |  add_loss(self, losses, inputs=None)
#  |      Adds losses to the layer.
#  |
#  |      The loss may potentially be conditional on some inputs tensors,
#  |      for instance activity losses are conditional on the layer's inputs.
#  |
#  |      # Arguments
#  |          losses: loss tensor or list of loss tensors
#  |              to add to the layer.
#  |          inputs: input tensor or list of inputs tensors to mark
#  |              the losses as conditional on these inputs.
#  |              If None is passed, the loss is assumed unconditional
#  |              (e.g. L2 weight regularization, which only depends
#  |              on the layer's weights variables, not on any inputs tensors).
#  |
#  |  add_update(self, updates, inputs=None)
#  |      Adds updates to the layer.
#  |
#  |      The updates may potentially be conditional on some inputs tensors,
#  |      for instance batch norm updates are conditional on the layer's inputs.
#  |
#  |      # Arguments
#  |          updates: update op or list of update ops
#  |              to add to the layer.
#  |          inputs: input tensor or list of inputs tensors to mark
#  |              the updates as conditional on these inputs.
#  |              If None is passed, the updates are assumed unconditional.
#  |
#  |  add_weight(self, name, shape, dtype=None, initializer=None, regularizer=None, trainable=True, constraint=None)
#  |      Adds a weight variable to the layer.
#  |
#  |      # Arguments
#  |          name: String, the name for the weight variable.
#  |          shape: The shape tuple of the weight.
#  |          dtype: The dtype of the weight.
#  |          initializer: An Initializer instance (callable).
#  |          regularizer: An optional Regularizer instance.
#  |          trainable: A boolean, whether the weight should
#  |              be trained via backprop or not (assuming
#  |              that the layer itself is also trainable).
#  |          constraint: An optional Constraint instance.
#  |
#  |      # Returns
#  |          The created weight variable.
#  |
#  |  assert_input_compatibility(self, inputs)
#  |      Checks compatibility between the layer and provided inputs.
#  |
#  |      This checks that the tensor(s) `input`
#  |      verify the input assumptions of the layer
#  |      (if any). If not, exceptions are raised.
#  |
#  |      # Arguments
#  |          inputs: input tensor or list of input tensors.
#  |
#  |      # Raises
#  |          ValueError: in case of mismatch between
#  |              the provided inputs and the expectations of the layer.
#  |
#  |  compute_mask(self, inputs, mask=None)
#  |      Computes an output mask tensor.
#  |
#  |      # Arguments
#  |          inputs: Tensor or list of tensors.
#  |          mask: Tensor or list of tensors.
#  |
#  |      # Returns
#  |          None or a tensor (or list of tensors,
#  |              one per output tensor of the layer).
#  |
#  |  count_params(self)
#  |      Counts the total number of scalars composing the weights.
#  |
#  |      # Returns
#  |          An integer count.
#  |
#  |      # Raises
#  |          RuntimeError: if the layer isn't yet built
#  |              (in which case its weights aren't yet defined).
#  |
#  |  get_input_at(self, node_index)
#  |      Retrieves the input tensor(s) of a layer at a given node.
#  |
#  |      # Arguments
#  |          node_index: Integer, index of the node
#  |              from which to retrieve the attribute.
#  |              E.g. `node_index=0` will correspond to the
#  |              first time the layer was called.
#  |
#  |      # Returns
#  |          A tensor (or list of tensors if the layer has multiple inputs).
#  |
#  |  get_input_mask_at(self, node_index)
#  |      Retrieves the input mask tensor(s) of a layer at a given node.
#  |
#  |      # Arguments
#  |          node_index: Integer, index of the node
#  |              from which to retrieve the attribute.
#  |              E.g. `node_index=0` will correspond to the
#  |              first time the layer was called.
#  |
#  |      # Returns
#  |          A mask tensor
#  |          (or list of tensors if the layer has multiple inputs).
#  |
#  |  get_input_shape_at(self, node_index)
#  |      Retrieves the input shape(s) of a layer at a given node.
#  |
#  |      # Arguments
#  |          node_index: Integer, index of the node
#  |              from which to retrieve the attribute.
#  |              E.g. `node_index=0` will correspond to the
#  |              first time the layer was called.
#  |
#  |      # Returns
#  |          A shape tuple
#  |          (or list of shape tuples if the layer has multiple inputs).
#  |
#  |  get_losses_for(self, inputs)
#  |
#  |  get_output_at(self, node_index)
#  |      Retrieves the output tensor(s) of a layer at a given node.
#  |
#  |      # Arguments
#  |          node_index: Integer, index of the node
#  |              from which to retrieve the attribute.
#  |              E.g. `node_index=0` will correspond to the
#  |              first time the layer was called.
#  |
#  |      # Returns
#  |          A tensor (or list of tensors if the layer has multiple outputs).
#  |
#  |  get_output_mask_at(self, node_index)
#  |      Retrieves the output mask tensor(s) of a layer at a given node.
#  |
#  |      # Arguments
#  |          node_index: Integer, index of the node
#  |              from which to retrieve the attribute.
#  |              E.g. `node_index=0` will correspond to the
#  |              first time the layer was called.
#  |
#  |      # Returns
#  |          A mask tensor
#  |          (or list of tensors if the layer has multiple outputs).
#  |
#  |  get_output_shape_at(self, node_index)
#  |      Retrieves the output shape(s) of a layer at a given node.
#  |
#  |      # Arguments
#  |          node_index: Integer, index of the node
#  |              from which to retrieve the attribute.
#  |              E.g. `node_index=0` will correspond to the
#  |              first time the layer was called.
#  |
#  |      # Returns
#  |          A shape tuple
#  |          (or list of shape tuples if the layer has multiple outputs).
#  |
#  |  get_updates_for(self, inputs)
#  |
#  |  get_weights(self)
#  |      Returns the current weights of the layer.
#  |
#  |      # Returns
#  |          Weights values as a list of numpy arrays.
#  |
#  |  set_weights(self, weights)
#  |      Sets the weights of the layer, from Numpy arrays.
#  |
#  |      # Arguments
#  |          weights: a list of Numpy arrays. The number
#  |              of arrays and their shape must match
#  |              number of the dimensions of the weights
#  |              of the layer (i.e. it should match the
#  |              output of `get_weights`).
#  |
#  |      # Raises
#  |          ValueError: If the provided weights list does not match the
#  |              layer's specifications.
#  |
#  |  ----------------------------------------------------------------------
#  |  Class methods inherited from keras.engine.base_layer.Layer:
#  |
#  |  from_config(config) from builtins.type
#  |      Creates a layer from its config.
#  |
#  |      This method is the reverse of `get_config`,
#  |      capable of instantiating the same layer from the config
#  |      dictionary. It does not handle layer connectivity
#  |      (handled by Network), nor weights (handled by `set_weights`).
#  |
#  |      # Arguments
#  |          config: A Python dictionary, typically the
#  |              output of get_config.
#  |
#  |      # Returns
#  |          A layer instance.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors inherited from keras.engine.base_layer.Layer:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)
#  |
#  |  built
#  |
#  |  input
#  |      Retrieves the input tensor(s) of a layer.
#  |
#  |      Only applicable if the layer has exactly one inbound node,
#  |      i.e. if it is connected to one incoming layer.
#  |
#  |      # Returns
#  |          Input tensor or list of input tensors.
#  |
#  |      # Raises
#  |          AttributeError: if the layer is connected to
#  |          more than one incoming layers.
#  |
#  |  input_mask
#  |      Retrieves the input mask tensor(s) of a layer.
#  |
#  |      Only applicable if the layer has exactly one inbound node,
#  |      i.e. if it is connected to one incoming layer.
#  |
#  |      # Returns
#  |          Input mask tensor (potentially None) or list of input
#  |          mask tensors.
#  |
#  |      # Raises
#  |          AttributeError: if the layer is connected to
#  |          more than one incoming layers.
#  |
#  |  input_shape
#  |      Retrieves the input shape tuple(s) of a layer.
#  |
#  |      Only applicable if the layer has exactly one inbound node,
#  |      i.e. if it is connected to one incoming layer.
#  |
#  |      # Returns
#  |          Input shape tuple
#  |          (or list of input shape tuples, one tuple per input tensor).
#  |
#  |      # Raises
#  |          AttributeError: if the layer is connected to
#  |          more than one incoming layers.
#  |
#  |  losses
#  |
#  |  non_trainable_weights
#  |
#  |  output
#  |      Retrieves the output tensor(s) of a layer.
#  |
#  |      Only applicable if the layer has exactly one inbound node,
#  |      i.e. if it is connected to one incoming layer.
#  |
#  |      # Returns
#  |          Output tensor or list of output tensors.
#  |
#  |      # Raises
#  |          AttributeError: if the layer is connected to
#  |          more than one incoming layers.
#  |
#  |  output_mask
#  |      Retrieves the output mask tensor(s) of a layer.
#  |
#  |      Only applicable if the layer has exactly one inbound node,
#  |      i.e. if it is connected to one incoming layer.
#  |
#  |      # Returns
#  |          Output mask tensor (potentially None) or list of output
#  |          mask tensors.
#  |
#  |      # Raises
#  |          AttributeError: if the layer is connected to
#  |          more than one incoming layers.
#  |
#  |  output_shape
#  |      Retrieves the output shape tuple(s) of a layer.
#  |
#  |      Only applicable if the layer has one inbound node,
#  |      or if all inbound nodes have the same output shape.
#  |
#  |      # Returns
#  |          Output shape tuple
#  |          (or list of input shape tuples, one tuple per output tensor).
#  |
#  |      # Raises
#  |          AttributeError: if the layer is connected to
#  |          more than one incoming layers.
#  |
#  |  trainable_weights
#  |
#  |  updates
#  |
#  |  weights

# %% [markdown]
# # Dsicriminator

# %%
model2 = models.Sequential()
model2.add(layers.Conv2D(64,(5,5),padding='same',input_shape=(28,28,1),activation='tanh'))
model2.add(layers.MaxPooling2D(pool_size=(2,2)))
model2.add(layers.Conv2D(128,(5,5),activation='tanh'))
model2.add(layers.MaxPooling2D(pool_size=(2,2)))
model2.add(layers.Flatten())
model2.add(layers.Dense(1024,activation='tanh'))
model2.add(layers.Dense(1,activation='sigmoid'))

# %% [markdown]
# # Final Model

# %%
model = models.Sequential()
model.add(model1)
model2.trainable = False
model.add(model2)

# %% [markdown]
# # load data

# %%
(trainimg,trainlb),(testimg,testlb) = mnist.load_data()
trainimg = trainimg/255
testimg = testimg/255
trainimg = trainimg.reshape(60000,28,28,1)
testimg = testimg.reshape(10000,28,28,1)

# %% [markdown]
# # Combining Images

# %%
def combine_images(g_images):
    num = g_images.shape[0] # getting the count of images
    width = int(numpy.sqrt(num))
    height = int(numpy.ceil(float(num)/width))
    imgshape = g_images[0].shape
    image = numpy.zeros((height*imgshape[0],width*imgshape[1]),dtype = g_images.dtype)
    for ind,img in enumerate(g_images):
        i = int(ind/width)
        j = ind % width
        image[i*imgshape[0]:(i+1)*imgshape[0],i*imgshape[1]:(j+1)*imgshape[1]] = img[:,:,0]
        return image

# %% [markdown]
# # Compilation

# %%
model1_optim = SGD(lr = 0.0005,momentum=0.9,nesterov=True)
model2_optim = SGD(lr = 0.0005,momentum=0.9,nesterov=True)
model1.compile(loss='binary_crossentropy',optimizer="SGD")
model.compile(loss='binary_crossentropy',optimizer=model1_optim)
model2.trainable = True
model2.compile(loss='binary_crossentropy',optimizer=model2_optim)
# training for 100 epochs
for i in range(100):
    print("Epoch is ",i)
    batch_size = 128
    for j in range(int(trainimg.shape[0]/batch_size)):
        noise = numpy.random.uniform(-1,1,size=(batch_size,100))
        img_batch = trainimg[j*batch_size:(j+1)*batch_size]
        g_images = model1.predict(noise,verbose=0)
        if j % 20 ==0:
            img = combine_images(g_images)
            img = img*127.5 + 127.5
            Image.fromarray(img.astype(numpy.uint8)[:28,:28]).save("generated_pictures\\"+str(i)+"_"+str(j)+".png")
            xtrain = numpy.concatenate((img_batch,g_images))
            ytrain = [1]*batch_size +[0] * batch_size
            model2_loss = model2.train_on_batch(xtrain,ytrain)
            print("batch %d discriminator loss : %f"%(j,model2_loss))
            noise = numpy.random.uniform(-1,1,(batch_size,100))
            model2.trainable = False
            model1_loss = model.train_on_batch(noise,[1]*batch_size)
            model2.trainable = True
            print("batch %d generator loss : %f"%(j,model1_loss))
# Out:
# Epoch is  0
# batch 0 discriminator loss : 0.708119
# batch 0 generator loss : 0.831357
# batch 20 discriminator loss : 0.663753
# batch 20 generator loss : 0.830319
# batch 40 discriminator loss : 0.662342
# batch 40 generator loss : 0.829116
# batch 60 discriminator loss : 0.658750
# batch 60 generator loss : 0.829065
# batch 80 discriminator loss : 0.661105
# batch 80 generator loss : 0.830729
# batch 100 discriminator loss : 0.655301
# batch 100 generator loss : 0.831700
# batch 120 discriminator loss : 0.645725
# batch 120 generator loss : 0.838457
# batch 140 discriminator loss : 0.640533
# batch 140 generator loss : 0.842123
# batch 160 discriminator loss : 0.627806
# batch 160 generator loss : 0.849596
# batch 180 discriminator loss : 0.629772
# batch 180 generator loss : 0.851282
# batch 200 discriminator loss : 0.622365
# batch 200 generator loss : 0.856646
# batch 220 discriminator loss : 0.618910
# batch 220 generator loss : 0.869758
# batch 240 discriminator loss : 0.611235
# batch 240 generator loss : 0.872737
# batch 260 discriminator loss : 0.609126
# batch 260 generator loss : 0.875134
# batch 280 discriminator loss : 0.610706
# batch 280 generator loss : 0.885812
# batch 300 discriminator loss : 0.597061
# batch 300 generator loss : 0.895345
# batch 320 discriminator loss : 0.589817
# batch 320 generator loss : 0.899590
# batch 340 discriminator loss : 0.581584
# batch 340 generator loss : 0.908068
# batch 360 discriminator loss : 0.579234
# batch 360 generator loss : 0.909454
# batch 380 discriminator loss : 0.563758
# batch 380 generator loss : 0.924050
# batch 400 discriminator loss : 0.540124
# batch 400 generator loss : 0.924231
# batch 420 discriminator loss : 0.563483
# batch 420 generator loss : 0.936901
# batch 440 discriminator loss : 0.548838
# batch 440 generator loss : 0.946027
# batch 460 discriminator loss : 0.539992
# batch 460 generator loss : 0.955162
# Epoch is  1
# batch 0 discriminator loss : 0.529075
# batch 0 generator loss : 0.958064
# batch 20 discriminator loss : 0.519228
# batch 20 generator loss : 0.974517
# batch 40 discriminator loss : 0.506683
# batch 40 generator loss : 0.980396
# batch 60 discriminator loss : 0.511106
# batch 60 generator loss : 0.984095
# batch 80 discriminator loss : 0.482479
# batch 80 generator loss : 0.986455
# batch 100 discriminator loss : 0.500908
# batch 100 generator loss : 0.997289
# batch 120 discriminator loss : 0.506444
# batch 120 generator loss : 1.007956
# batch 140 discriminator loss : 0.489886
# batch 140 generator loss : 1.011018
# batch 160 discriminator loss : 0.464599
# batch 160 generator loss : 1.025295
# batch 180 discriminator loss : 0.459313
# batch 180 generator loss : 1.030429
# batch 200 discriminator loss : 0.464090
# batch 200 generator loss : 1.029618
# batch 220 discriminator loss : 0.455630
# batch 220 generator loss : 1.045704
# batch 240 discriminator loss : 0.459240
# batch 240 generator loss : 1.038947
# batch 260 discriminator loss : 0.459997
# batch 260 generator loss : 1.031418
# batch 280 discriminator loss : 0.477238
# batch 280 generator loss : 1.039564
# batch 300 discriminator loss : 0.459074
# batch 300 generator loss : 1.044852
# batch 320 discriminator loss : 0.446468
# batch 320 generator loss : 1.044395
# batch 340 discriminator loss : 0.443575
# batch 340 generator loss : 1.051522
# batch 360 discriminator loss : 0.451986
# batch 360 generator loss : 1.035482
# batch 380 discriminator loss : 0.439639
# batch 380 generator loss : 1.039044
# batch 400 discriminator loss : 0.421576
# batch 400 generator loss : 1.031537
# batch 420 discriminator loss : 0.453513
# batch 420 generator loss : 1.029545
# batch 440 discriminator loss : 0.444057
# batch 440 generator loss : 1.012661
# batch 460 discriminator loss : 0.436116
# batch 460 generator loss : 0.993940
# Epoch is  2
# batch 0 discriminator loss : 0.432923
# batch 0 generator loss : 0.987993
# batch 20 discriminator loss : 0.428003
# batch 20 generator loss : 0.989700
# batch 40 discriminator loss : 0.452461
# batch 40 generator loss : 0.976354
# batch 60 discriminator loss : 0.446750
# batch 60 generator loss : 0.970234
# batch 80 discriminator loss : 0.420838
# batch 80 generator loss : 0.963935
# batch 100 discriminator loss : 0.464506
# batch 100 generator loss : 0.923444
# batch 120 discriminator loss : 0.472233
# batch 120 generator loss : 0.914814
# batch 140 discriminator loss : 0.476041
# batch 140 generator loss : 0.906228
# batch 160 discriminator loss : 0.450994
# batch 160 generator loss : 0.912181
# batch 180 discriminator loss : 0.462176
# batch 180 generator loss : 0.902189
# batch 200 discriminator loss : 0.482230
# batch 200 generator loss : 0.893577
# batch 220 discriminator loss : 0.473235
# batch 220 generator loss : 0.895475
# batch 240 discriminator loss : 0.504986
# batch 240 generator loss : 0.884338
# batch 260 discriminator loss : 0.498079
# batch 260 generator loss : 0.892177
# batch 280 discriminator loss : 0.530886
# batch 280 generator loss : 0.882430
# batch 300 discriminator loss : 0.522030
# batch 300 generator loss : 0.869587
# batch 320 discriminator loss : 0.540170
# batch 320 generator loss : 0.857663
# batch 340 discriminator loss : 0.541654
# batch 340 generator loss : 0.877359
# batch 360 discriminator loss : 0.525924
# batch 360 generator loss : 0.904603
# batch 380 discriminator loss : 0.529773
# batch 380 generator loss : 0.904381
# batch 400 discriminator loss : 0.498450
# batch 400 generator loss : 0.913904
# batch 420 discriminator loss : 0.554624
# batch 420 generator loss : 0.942075
# batch 440 discriminator loss : 0.547005
# batch 440 generator loss : 0.945872
# batch 460 discriminator loss : 0.536413
# batch 460 generator loss : 0.979259
# Epoch is  3
# batch 0 discriminator loss : 0.527404
# batch 0 generator loss : 1.001950
# batch 20 discriminator loss : 0.525336
# batch 20 generator loss : 1.040903
# batch 40 discriminator loss : 0.519946
# batch 40 generator loss : 1.062453
# batch 60 discriminator loss : 0.524486
# batch 60 generator loss : 1.107629
# batch 80 discriminator loss : 0.489338
# batch 80 generator loss : 1.174974
# batch 100 discriminator loss : 0.533127
# batch 100 generator loss : 1.196800
# batch 120 discriminator loss : 0.521871
# batch 120 generator loss : 1.250210
# batch 140 discriminator loss : 0.494571
# batch 140 generator loss : 1.299842
# batch 160 discriminator loss : 0.495324
# batch 160 generator loss : 1.319899
# batch 180 discriminator loss : 0.490948
# batch 180 generator loss : 1.391568
# batch 200 discriminator loss : 0.510275
# batch 200 generator loss : 1.416683
# batch 220 discriminator loss : 0.494584
# batch 220 generator loss : 1.452912
# batch 240 discriminator loss : 0.492524
# batch 240 generator loss : 1.484865
# batch 260 discriminator loss : 0.502496
# batch 260 generator loss : 1.512878
# batch 280 discriminator loss : 0.514005
# batch 280 generator loss : 1.534984
# batch 300 discriminator loss : 0.476925
# batch 300 generator loss : 1.578620
# batch 320 discriminator loss : 0.478336
# batch 320 generator loss : 1.588817
# batch 340 discriminator loss : 0.464226
# batch 340 generator loss : 1.635047
# batch 360 discriminator loss : 0.454739
# batch 360 generator loss : 1.645574
# batch 380 discriminator loss : 0.447299
# batch 380 generator loss : 1.666148
# batch 400 discriminator loss : 0.398974
# batch 400 generator loss : 1.684605
# batch 420 discriminator loss : 0.430243
# batch 420 generator loss : 1.696681
# batch 440 discriminator loss : 0.396147
# batch 440 generator loss : 1.707872
# batch 460 discriminator loss : 0.410001
# batch 460 generator loss : 1.737967
# Epoch is  4
# batch 0 discriminator loss : 0.384233
# batch 0 generator loss : 1.753313
# batch 20 discriminator loss : 0.369973
# batch 20 generator loss : 1.746077
# batch 40 discriminator loss : 0.361569
# batch 40 generator loss : 1.773428
# batch 60 discriminator loss : 0.342395
# batch 60 generator loss : 1.776910
# batch 80 discriminator loss : 0.330797
# batch 80 generator loss : 1.814416
# batch 100 discriminator loss : 0.352098
# batch 100 generator loss : 1.831802
# batch 120 discriminator loss : 0.333819
# batch 120 generator loss : 1.864218
# batch 140 discriminator loss : 0.306064
# batch 140 generator loss : 1.866745
# batch 160 discriminator loss : 0.297299
# batch 160 generator loss : 1.876259
# batch 180 discriminator loss : 0.304422
# batch 180 generator loss : 1.901036
# batch 200 discriminator loss : 0.311721
# batch 200 generator loss : 1.922040
# batch 220 discriminator loss : 0.295426
# batch 220 generator loss : 1.951849
# batch 240 discriminator loss : 0.278228
# batch 240 generator loss : 1.970898
# batch 260 discriminator loss : 0.289874
# batch 260 generator loss : 1.960992
# batch 280 discriminator loss : 0.304506
# batch 280 generator loss : 1.989525
# batch 300 discriminator loss : 0.264588
# batch 300 generator loss : 2.027605
# batch 320 discriminator loss : 0.269641
# batch 320 generator loss : 2.012894
# batch 340 discriminator loss : 0.265015
# batch 340 generator loss : 2.023075
# batch 360 discriminator loss : 0.255763
# batch 360 generator loss : 2.050796
# batch 380 discriminator loss : 0.255544
# batch 380 generator loss : 2.062482
# batch 400 discriminator loss : 0.217410
# batch 400 generator loss : 2.052361
# batch 420 discriminator loss : 0.251451
# batch 420 generator loss : 2.087202
# batch 440 discriminator loss : 0.225909
# batch 440 generator loss : 2.123839
# batch 460 discriminator loss : 0.235289
# batch 460 generator loss : 2.114729
# Epoch is  5
# batch 0 discriminator loss : 0.226064
# batch 0 generator loss : 2.157352
# batch 20 discriminator loss : 0.214140
# batch 20 generator loss : 2.158709
# batch 40 discriminator loss : 0.220054
# batch 40 generator loss : 2.187476
# batch 60 discriminator loss : 0.205045
# batch 60 generator loss : 2.156475
# batch 80 discriminator loss : 0.220071
# batch 80 generator loss : 2.157058
# batch 100 discriminator loss : 0.221758
# batch 100 generator loss : 2.179785
# batch 120 discriminator loss : 0.238519
# batch 120 generator loss : 2.197220
# batch 140 discriminator loss : 0.204291
# batch 140 generator loss : 2.196176
# batch 160 discriminator loss : 0.204794
# batch 160 generator loss : 2.232481
# batch 180 discriminator loss : 0.243301
# batch 180 generator loss : 2.211930
# batch 200 discriminator loss : 0.236168
# batch 200 generator loss : 2.166594
# batch 220 discriminator loss : 0.251999
# batch 220 generator loss : 2.126805
# batch 240 discriminator loss : 0.235855
# batch 240 generator loss : 2.145013
# batch 260 discriminator loss : 0.265377
# batch 260 generator loss : 2.187940
# batch 280 discriminator loss : 0.308860
# batch 280 generator loss : 2.223873
# batch 300 discriminator loss : 0.254118
# batch 300 generator loss : 2.149272
# batch 320 discriminator loss : 0.266941
# batch 320 generator loss : 2.133832
# batch 340 discriminator loss : 0.282608
# batch 340 generator loss : 2.095118
# batch 360 discriminator loss : 0.295530
# batch 360 generator loss : 2.077797
# batch 380 discriminator loss : 0.335515
# batch 380 generator loss : 2.014509
# batch 400 discriminator loss : 0.289848
# batch 400 generator loss : 1.971123
# batch 420 discriminator loss : 0.399570
# batch 420 generator loss : 1.993905
# batch 440 discriminator loss : 0.337760
# batch 440 generator loss : 2.033761
# batch 460 discriminator loss : 0.356917
# batch 460 generator loss : 2.034591
# Epoch is  6
# batch 0 discriminator loss : 0.324180
# batch 0 generator loss : 2.009397
# batch 20 discriminator loss : 0.390069
# batch 20 generator loss : 1.952575
# batch 40 discriminator loss : 0.375637
# batch 40 generator loss : 1.930135
# batch 60 discriminator loss : 0.411562
# batch 60 generator loss : 1.797963
# batch 80 discriminator loss : 0.420975
# batch 80 generator loss : 1.853858
# batch 100 discriminator loss : 0.445452
# batch 100 generator loss : 1.728286
# batch 120 discriminator loss : 0.404930
# batch 120 generator loss : 1.764942
# batch 140 discriminator loss : 0.431576
# batch 140 generator loss : 1.742806
# batch 160 discriminator loss : 0.431364
# batch 160 generator loss : 1.675506
# batch 180 discriminator loss : 0.435212
# batch 180 generator loss : 1.721213
# batch 200 discriminator loss : 0.446314
# batch 200 generator loss : 1.730315
# batch 220 discriminator loss : 0.507893
# batch 220 generator loss : 1.601156
# batch 240 discriminator loss : 0.459260
# batch 240 generator loss : 1.520392
# batch 260 discriminator loss : 0.523657
# batch 260 generator loss : 1.666786
# batch 280 discriminator loss : 0.417321
# batch 280 generator loss : 1.464257
# batch 300 discriminator loss : 0.442717
# batch 300 generator loss : 1.327398
# batch 320 discriminator loss : 0.487153
# batch 320 generator loss : 1.446774
# batch 340 discriminator loss : 0.441044
# batch 340 generator loss : 1.410603
# batch 360 discriminator loss : 0.488892
# batch 360 generator loss : 1.441858
# batch 380 discriminator loss : 0.496753
# batch 380 generator loss : 1.304578
# batch 400 discriminator loss : 0.472122
# batch 400 generator loss : 1.316893
# batch 420 discriminator loss : 0.554279
# batch 420 generator loss : 1.206803
# batch 440 discriminator loss : 0.454642
# batch 440 generator loss : 1.251603
# batch 460 discriminator loss : 0.458826
# batch 460 generator loss : 1.279050
# Epoch is  7
# batch 0 discriminator loss : 0.516686
# batch 0 generator loss : 1.282657
# batch 20 discriminator loss : 0.515311
# batch 20 generator loss : 1.110058
# batch 40 discriminator loss : 0.542410
# batch 40 generator loss : 1.252775
# batch 60 discriminator loss : 0.487520
# batch 60 generator loss : 1.098666
# batch 80 discriminator loss : 0.451779
# batch 80 generator loss : 1.178842
# batch 100 discriminator loss : 0.513067
# batch 100 generator loss : 1.235211
# batch 120 discriminator loss : 0.492130
# batch 120 generator loss : 1.059213
# batch 140 discriminator loss : 0.476681
# batch 140 generator loss : 1.181599
# batch 160 discriminator loss : 0.463106
# batch 160 generator loss : 1.211269
# batch 180 discriminator loss : 0.497669
# batch 180 generator loss : 1.143203
# batch 200 discriminator loss : 0.495790
# batch 200 generator loss : 1.120102
# batch 220 discriminator loss : 0.505392
# batch 220 generator loss : 1.151640
# batch 240 discriminator loss : 0.457515
# batch 240 generator loss : 1.229140
# batch 260 discriminator loss : 0.504586
# batch 260 generator loss : 1.167894
# batch 280 discriminator loss : 0.485934
# batch 280 generator loss : 1.099471
# batch 300 discriminator loss : 0.491785
# batch 300 generator loss : 1.175077
# batch 320 discriminator loss : 0.502119
# batch 320 generator loss : 1.210109
# batch 340 discriminator loss : 0.476513
# batch 340 generator loss : 1.181326
# batch 360 discriminator loss : 0.500582
# batch 360 generator loss : 1.058877
# batch 380 discriminator loss : 0.479618
# batch 380 generator loss : 1.216033
# batch 400 discriminator loss : 0.466015
# batch 400 generator loss : 1.228961
# batch 420 discriminator loss : 0.451894
# batch 420 generator loss : 1.182319
# batch 440 discriminator loss : 0.422881
# batch 440 generator loss : 1.192645
# batch 460 discriminator loss : 0.437088
# batch 460 generator loss : 1.169470
# Epoch is  8
# batch 0 discriminator loss : 0.443654
# batch 0 generator loss : 1.243697
# batch 20 discriminator loss : 0.419170
# batch 20 generator loss : 1.148347
# batch 40 discriminator loss : 0.414097
# batch 40 generator loss : 1.198121
# batch 60 discriminator loss : 0.478996
# batch 60 generator loss : 1.229620
# batch 80 discriminator loss : 0.428295
# batch 80 generator loss : 1.269337
# batch 100 discriminator loss : 0.448328
# batch 100 generator loss : 1.293788
# batch 120 discriminator loss : 0.463422
# batch 120 generator loss : 1.191444
# batch 140 discriminator loss : 0.423778
# batch 140 generator loss : 1.306172
# batch 160 discriminator loss : 0.424378
# batch 160 generator loss : 1.226302
# batch 180 discriminator loss : 0.422905
# batch 180 generator loss : 1.296011
# batch 200 discriminator loss : 0.432915
# batch 200 generator loss : 1.284171
# batch 220 discriminator loss : 0.414857
# batch 220 generator loss : 1.239953
# batch 240 discriminator loss : 0.432233
# batch 240 generator loss : 1.295651
# batch 260 discriminator loss : 0.439158
# batch 260 generator loss : 1.264234
# batch 280 discriminator loss : 0.455174
# batch 280 generator loss : 1.404184
# batch 300 discriminator loss : 0.430347
# batch 300 generator loss : 1.331407
# batch 320 discriminator loss : 0.401141
# batch 320 generator loss : 1.343026
# batch 340 discriminator loss : 0.409642
# batch 340 generator loss : 1.348096
# batch 360 discriminator loss : 0.425397
# batch 360 generator loss : 1.451874
# batch 380 discriminator loss : 0.401325
# batch 380 generator loss : 1.396013
# batch 400 discriminator loss : 0.373182
# batch 400 generator loss : 1.365291
# batch 420 discriminator loss : 0.432031
# batch 420 generator loss : 1.381434
# batch 440 discriminator loss : 0.368304
# batch 440 generator loss : 1.451119
# batch 460 discriminator loss : 0.398676
# batch 460 generator loss : 1.411708
# Epoch is  9
# batch 0 discriminator loss : 0.401138
# batch 0 generator loss : 1.358085
# batch 20 discriminator loss : 0.383380
# batch 20 generator loss : 1.401376
# batch 40 discriminator loss : 0.361635
# batch 40 generator loss : 1.461689
# batch 60 discriminator loss : 0.378116
# batch 60 generator loss : 1.350652
# batch 80 discriminator loss : 0.343570
# batch 80 generator loss : 1.411686
# batch 100 discriminator loss : 0.414115
# batch 100 generator loss : 1.383673
# batch 120 discriminator loss : 0.399898
# batch 120 generator loss : 1.460570
# batch 140 discriminator loss : 0.397634
# batch 140 generator loss : 1.454684
# batch 160 discriminator loss : 0.370515
# batch 160 generator loss : 1.406237
# batch 180 discriminator loss : 0.367816
# batch 180 generator loss : 1.470665
# batch 200 discriminator loss : 0.389086
# batch 200 generator loss : 1.438147
# batch 220 discriminator loss : 0.383768
# batch 220 generator loss : 1.462210
# batch 240 discriminator loss : 0.412176
# batch 240 generator loss : 1.445446
# batch 260 discriminator loss : 0.417975
# batch 260 generator loss : 1.521503
# batch 280 discriminator loss : 0.413196
# batch 280 generator loss : 1.453118
# batch 300 discriminator loss : 0.388508
# batch 300 generator loss : 1.522459
# batch 320 discriminator loss : 0.394014
# batch 320 generator loss : 1.514071
# batch 340 discriminator loss : 0.427820
# batch 340 generator loss : 1.505727
# batch 360 discriminator loss : 0.415127
# batch 360 generator loss : 1.484317
# batch 380 discriminator loss : 0.399972
# batch 380 generator loss : 1.436069
# batch 400 discriminator loss : 0.399500
# batch 400 generator loss : 1.471472
# batch 420 discriminator loss : 0.424746
# batch 420 generator loss : 1.549251
# batch 440 discriminator loss : 0.396069
# batch 440 generator loss : 1.509794
# batch 460 discriminator loss : 0.403361
# batch 460 generator loss : 1.580609
# Epoch is  10
# batch 0 discriminator loss : 0.401091
# batch 0 generator loss : 1.515920
# batch 20 discriminator loss : 0.382935
# batch 20 generator loss : 1.497172
# batch 40 discriminator loss : 0.386264
# batch 40 generator loss : 1.570631
# batch 60 discriminator loss : 0.411586
# batch 60 generator loss : 1.541614
# batch 80 discriminator loss : 0.376891
# batch 80 generator loss : 1.518725
# batch 100 discriminator loss : 0.428659
# batch 100 generator loss : 1.551904
# batch 120 discriminator loss : 0.440821
# batch 120 generator loss : 1.606627
# batch 140 discriminator loss : 0.411549
# batch 140 generator loss : 1.544204
# batch 160 discriminator loss : 0.392118
# batch 160 generator loss : 1.599188
# batch 180 discriminator loss : 0.393537
# batch 180 generator loss : 1.590894
# batch 200 discriminator loss : 0.421391
# batch 200 generator loss : 1.563001
# batch 220 discriminator loss : 0.392103
# batch 220 generator loss : 1.507699
# batch 240 discriminator loss : 0.424776
# batch 240 generator loss : 1.602213
# batch 260 discriminator loss : 0.419969
# batch 260 generator loss : 1.512962
# batch 280 discriminator loss : 0.437096
# batch 280 generator loss : 1.643626
# batch 300 discriminator loss : 0.400200
# batch 300 generator loss : 1.707972
# batch 320 discriminator loss : 0.431523
# batch 320 generator loss : 1.612342
# batch 340 discriminator loss : 0.424074
# batch 340 generator loss : 1.591800
# batch 360 discriminator loss : 0.427404
# batch 360 generator loss : 1.648746
# batch 380 discriminator loss : 0.403513
# batch 380 generator loss : 1.586154
# batch 400 discriminator loss : 0.399767
# batch 400 generator loss : 1.637005
# batch 420 discriminator loss : 0.407226
# batch 420 generator loss : 1.624329
# batch 440 discriminator loss : 0.396136
# batch 440 generator loss : 1.668595
# batch 460 discriminator loss : 0.408160
# batch 460 generator loss : 1.702888
# Epoch is  11
# batch 0 discriminator loss : 0.419345
# batch 0 generator loss : 1.659115
# batch 20 discriminator loss : 0.358796
# batch 20 generator loss : 1.685068
# batch 40 discriminator loss : 0.378749
# batch 40 generator loss : 1.676154
# batch 60 discriminator loss : 0.413095
# batch 60 generator loss : 1.691623
# batch 80 discriminator loss : 0.362298
# batch 80 generator loss : 1.705465
# batch 100 discriminator loss : 0.405255
# batch 100 generator loss : 1.637886
# batch 120 discriminator loss : 0.403451
# batch 120 generator loss : 1.760233
# batch 140 discriminator loss : 0.395651
# batch 140 generator loss : 1.638088
# batch 160 discriminator loss : 0.360529
# batch 160 generator loss : 1.644742
# batch 180 discriminator loss : 0.357940
# batch 180 generator loss : 1.782774
# batch 200 discriminator loss : 0.367002
# batch 200 generator loss : 1.819223
# batch 220 discriminator loss : 0.371990
# batch 220 generator loss : 1.725733
# batch 240 discriminator loss : 0.379542
# batch 240 generator loss : 1.784245
# batch 260 discriminator loss : 0.367565
# batch 260 generator loss : 1.735133
# batch 280 discriminator loss : 0.371729
# batch 280 generator loss : 1.848584
# batch 300 discriminator loss : 0.334086
# batch 300 generator loss : 1.859389
# batch 320 discriminator loss : 0.348208
# batch 320 generator loss : 1.883975
# batch 340 discriminator loss : 0.358674
# batch 340 generator loss : 1.842597
# batch 360 discriminator loss : 0.361737
# batch 360 generator loss : 1.800177
# batch 380 discriminator loss : 0.330665
# batch 380 generator loss : 1.878120
# batch 400 discriminator loss : 0.341237
# batch 400 generator loss : 1.803634
# batch 420 discriminator loss : 0.322886
# batch 420 generator loss : 1.895622
# batch 440 discriminator loss : 0.320622
# batch 440 generator loss : 1.930318
# batch 460 discriminator loss : 0.340681
# batch 460 generator loss : 1.912448
# Epoch is  12
# batch 0 discriminator loss : 0.325543
# batch 0 generator loss : 1.946915
# batch 20 discriminator loss : 0.301988
# batch 20 generator loss : 1.943931
# batch 40 discriminator loss : 0.329091
# batch 40 generator loss : 1.914161
# batch 60 discriminator loss : 0.319921
# batch 60 generator loss : 1.942663
# batch 80 discriminator loss : 0.312608
# batch 80 generator loss : 1.917946
# batch 100 discriminator loss : 0.319470
# batch 100 generator loss : 1.830031
# batch 120 discriminator loss : 0.317177
# batch 120 generator loss : 1.849761
# batch 140 discriminator loss : 0.296070
# batch 140 generator loss : 1.896449
# batch 160 discriminator loss : 0.287695
# batch 160 generator loss : 1.862481
# batch 180 discriminator loss : 0.303586
# batch 180 generator loss : 1.867554
# batch 200 discriminator loss : 0.302385
# batch 200 generator loss : 1.905113
# batch 220 discriminator loss : 0.295410
# batch 220 generator loss : 1.938730
# batch 240 discriminator loss : 0.296035
# batch 240 generator loss : 1.865763
# batch 260 discriminator loss : 0.299598
# batch 260 generator loss : 1.910892
# batch 280 discriminator loss : 0.286815
# batch 280 generator loss : 1.933890
# batch 300 discriminator loss : 0.290485
# batch 300 generator loss : 1.943474
# batch 320 discriminator loss : 0.284512
# batch 320 generator loss : 1.946784
# batch 340 discriminator loss : 0.280177
# batch 340 generator loss : 1.859457
# batch 360 discriminator loss : 0.291428
# batch 360 generator loss : 1.920515
# batch 380 discriminator loss : 0.286033
# batch 380 generator loss : 1.927205
# batch 400 discriminator loss : 0.298282
# batch 400 generator loss : 1.957646
# batch 420 discriminator loss : 0.277606
# batch 420 generator loss : 1.929171
# batch 440 discriminator loss : 0.277753
# batch 440 generator loss : 1.990305
# batch 460 discriminator loss : 0.266153
# batch 460 generator loss : 1.867490
# Epoch is  13
# batch 0 discriminator loss : 0.274083
# batch 0 generator loss : 1.893893
# batch 20 discriminator loss : 0.280313
# batch 20 generator loss : 1.941714
# batch 40 discriminator loss : 0.272813
# batch 40 generator loss : 1.915955
# batch 60 discriminator loss : 0.290500
# batch 60 generator loss : 1.892645
# batch 80 discriminator loss : 0.296295
# batch 80 generator loss : 1.891682
# batch 100 discriminator loss : 0.276446
# batch 100 generator loss : 1.818779
# batch 120 discriminator loss : 0.264845
# batch 120 generator loss : 1.919831
# batch 140 discriminator loss : 0.257772
# batch 140 generator loss : 1.805121
# batch 160 discriminator loss : 0.276990
# batch 160 generator loss : 1.832626
# batch 180 discriminator loss : 0.278590
# batch 180 generator loss : 1.807084
# batch 200 discriminator loss : 0.265576
# batch 200 generator loss : 1.800975
# batch 220 discriminator loss : 0.288414
# batch 220 generator loss : 1.785267
# batch 240 discriminator loss : 0.280076
# batch 240 generator loss : 1.755094
# batch 260 discriminator loss : 0.259291
# batch 260 generator loss : 1.815460
# batch 280 discriminator loss : 0.268083
# batch 280 generator loss : 1.674896
# batch 300 discriminator loss : 0.264199
# batch 300 generator loss : 1.695714
# batch 320 discriminator loss : 0.268189
# batch 320 generator loss : 1.685973
# batch 340 discriminator loss : 0.275206
# batch 340 generator loss : 1.687716
# batch 360 discriminator loss : 0.269193
# batch 360 generator loss : 1.688791
# batch 380 discriminator loss : 0.265521
# batch 380 generator loss : 1.664970
# batch 400 discriminator loss : 0.309650
# batch 400 generator loss : 1.738651
# batch 420 discriminator loss : 0.265296
# batch 420 generator loss : 1.692666
# batch 440 discriminator loss : 0.246802
# batch 440 generator loss : 1.696067
# batch 460 discriminator loss : 0.277872
# batch 460 generator loss : 1.766367
# Epoch is  14
# batch 0 discriminator loss : 0.268570
# batch 0 generator loss : 1.716361
# batch 20 discriminator loss : 0.251178
# batch 20 generator loss : 1.721386
# batch 40 discriminator loss : 0.268573
# batch 40 generator loss : 1.645051
# batch 60 discriminator loss : 0.255705
# batch 60 generator loss : 1.668737
# batch 80 discriminator loss : 0.283176
# batch 80 generator loss : 1.563175
# batch 100 discriminator loss : 0.239174
# batch 100 generator loss : 1.704793
# batch 120 discriminator loss : 0.253919
# batch 120 generator loss : 1.717472
# batch 140 discriminator loss : 0.248738
# batch 140 generator loss : 1.821830
# batch 160 discriminator loss : 0.236855
# batch 160 generator loss : 1.732514
# batch 180 discriminator loss : 0.245372
# batch 180 generator loss : 1.607903
# batch 200 discriminator loss : 0.241194
# batch 200 generator loss : 1.698178
# batch 220 discriminator loss : 0.243278
# batch 220 generator loss : 1.752098
# batch 240 discriminator loss : 0.242602
# batch 240 generator loss : 1.739256
# batch 260 discriminator loss : 0.226797
# batch 260 generator loss : 1.734514
# batch 280 discriminator loss : 0.236150
# batch 280 generator loss : 1.748435
# batch 300 discriminator loss : 0.212812
# batch 300 generator loss : 1.767448
# batch 320 discriminator loss : 0.234060
# batch 320 generator loss : 1.742923
# batch 340 discriminator loss : 0.224843
# batch 340 generator loss : 1.753816
# batch 360 discriminator loss : 0.220269
# batch 360 generator loss : 1.701055
# batch 380 discriminator loss : 0.218977
# batch 380 generator loss : 1.797148
# batch 400 discriminator loss : 0.216385
# batch 400 generator loss : 1.771511
# batch 420 discriminator loss : 0.224670
# batch 420 generator loss : 1.821864
# batch 440 discriminator loss : 0.212567
# batch 440 generator loss : 1.881433
# batch 460 discriminator loss : 0.211368
# batch 460 generator loss : 1.769608
# Epoch is  15
# batch 0 discriminator loss : 0.204278
# batch 0 generator loss : 1.784903
# batch 20 discriminator loss : 0.201956
# batch 20 generator loss : 1.821313
# batch 40 discriminator loss : 0.202820
# batch 40 generator loss : 1.943951
# batch 60 discriminator loss : 0.209831
# batch 60 generator loss : 1.867701
# batch 80 discriminator loss : 0.219088
# batch 80 generator loss : 1.796182
# batch 100 discriminator loss : 0.201984
# batch 100 generator loss : 1.813168
# batch 120 discriminator loss : 0.207463
# batch 120 generator loss : 1.825959
# batch 140 discriminator loss : 0.201537
# batch 140 generator loss : 1.849910
# batch 160 discriminator loss : 0.190018
# batch 160 generator loss : 1.832789
# batch 180 discriminator loss : 0.205651
# batch 180 generator loss : 1.841964
# batch 200 discriminator loss : 0.207885
# batch 200 generator loss : 1.796768
# batch 220 discriminator loss : 0.205934
# batch 220 generator loss : 1.932738
# batch 240 discriminator loss : 0.201042
# batch 240 generator loss : 1.760949
# batch 260 discriminator loss : 0.195856
# batch 260 generator loss : 1.813510
# batch 280 discriminator loss : 0.200223
# batch 280 generator loss : 1.830928
# batch 300 discriminator loss : 0.210081
# batch 300 generator loss : 1.898336
# batch 320 discriminator loss : 0.198905
# batch 320 generator loss : 1.849702
# batch 340 discriminator loss : 0.191842
# batch 340 generator loss : 1.903733
# batch 360 discriminator loss : 0.197903
# batch 360 generator loss : 1.835012
# batch 380 discriminator loss : 0.190591
# batch 380 generator loss : 1.863251
# batch 400 discriminator loss : 0.193622
# batch 400 generator loss : 1.870414
# batch 420 discriminator loss : 0.207640
# batch 420 generator loss : 1.911860
# batch 440 discriminator loss : 0.186831
# batch 440 generator loss : 1.868356
# batch 460 discriminator loss : 0.191443
# batch 460 generator loss : 1.940958
# Epoch is  16
# batch 0 discriminator loss : 0.191117
# batch 0 generator loss : 1.794435
# batch 20 discriminator loss : 0.187171
# batch 20 generator loss : 1.895229
# batch 40 discriminator loss : 0.204922
# batch 40 generator loss : 1.970341
# batch 60 discriminator loss : 0.210016
# batch 60 generator loss : 1.886303
# batch 80 discriminator loss : 0.205606
# batch 80 generator loss : 1.921712
# batch 100 discriminator loss : 0.199569
# batch 100 generator loss : 1.882233
# batch 120 discriminator loss : 0.201637
# batch 120 generator loss : 1.940588
# batch 140 discriminator loss : 0.191166
# batch 140 generator loss : 1.878280
# batch 160 discriminator loss : 0.194877
# batch 160 generator loss : 1.843830
# batch 180 discriminator loss : 0.219954
# batch 180 generator loss : 1.837817
# batch 200 discriminator loss : 0.214733
# batch 200 generator loss : 1.889653
# batch 220 discriminator loss : 0.205946
# batch 220 generator loss : 1.905461
# batch 240 discriminator loss : 0.206656
# batch 240 generator loss : 1.924593
# batch 260 discriminator loss : 0.217419
# batch 260 generator loss : 1.835869
# batch 280 discriminator loss : 0.217435
# batch 280 generator loss : 1.900327
# batch 300 discriminator loss : 0.208201
# batch 300 generator loss : 1.829938
# batch 320 discriminator loss : 0.221095
# batch 320 generator loss : 1.997433
# batch 340 discriminator loss : 0.215249
# batch 340 generator loss : 1.928255
# batch 360 discriminator loss : 0.214034
# batch 360 generator loss : 1.912328
# batch 380 discriminator loss : 0.213368
# batch 380 generator loss : 1.921015
# batch 400 discriminator loss : 0.215410
# batch 400 generator loss : 2.010108
# batch 420 discriminator loss : 0.204677
# batch 420 generator loss : 1.933944
# batch 440 discriminator loss : 0.214718
# batch 440 generator loss : 1.936725
# batch 460 discriminator loss : 0.221931
# batch 460 generator loss : 1.921108
# Epoch is  17
# batch 0 discriminator loss : 0.205432
# batch 0 generator loss : 1.815447
# batch 20 discriminator loss : 0.229833
# batch 20 generator loss : 1.945607
# batch 40 discriminator loss : 0.228852
# batch 40 generator loss : 1.851303
# batch 60 discriminator loss : 0.225837
# batch 60 generator loss : 1.775459
# batch 80 discriminator loss : 0.254142
# batch 80 generator loss : 1.780222
# batch 100 discriminator loss : 0.228952
# batch 100 generator loss : 1.786242
# batch 120 discriminator loss : 0.225587
# batch 120 generator loss : 1.810627
# batch 140 discriminator loss : 0.217920
# batch 140 generator loss : 1.784678
# batch 160 discriminator loss : 0.226646
# batch 160 generator loss : 1.751322
# batch 180 discriminator loss : 0.240425
# batch 180 generator loss : 1.696387
# batch 200 discriminator loss : 0.246446
# batch 200 generator loss : 1.751500
# batch 220 discriminator loss : 0.239289
# batch 220 generator loss : 1.739074
# batch 240 discriminator loss : 0.250135
# batch 240 generator loss : 1.720149
# batch 260 discriminator loss : 0.256495
# batch 260 generator loss : 1.694699
# batch 280 discriminator loss : 0.244460
# batch 280 generator loss : 1.715288
# batch 300 discriminator loss : 0.245016
# batch 300 generator loss : 1.621110
# batch 320 discriminator loss : 0.265444
# batch 320 generator loss : 1.614465
# batch 340 discriminator loss : 0.261467
# batch 340 generator loss : 1.608963
# batch 360 discriminator loss : 0.280084
# batch 360 generator loss : 1.538055
# batch 380 discriminator loss : 0.279057
# batch 380 generator loss : 1.542642
# batch 400 discriminator loss : 0.295981
# batch 400 generator loss : 1.379903
# batch 420 discriminator loss : 0.288144
# batch 420 generator loss : 1.479295
# batch 440 discriminator loss : 0.318150
# batch 440 generator loss : 1.350481
# batch 460 discriminator loss : 0.331363
# batch 460 generator loss : 1.332598
# Epoch is  18
# batch 0 discriminator loss : 0.336334
# batch 0 generator loss : 1.193398
# batch 20 discriminator loss : 0.341498
# batch 20 generator loss : 1.117908
# batch 40 discriminator loss : 0.367230
# batch 40 generator loss : 1.085134
# batch 60 discriminator loss : 0.379236
# batch 60 generator loss : 1.040801
# batch 80 discriminator loss : 0.432746
# batch 80 generator loss : 0.964757
# batch 100 discriminator loss : 0.399465
# batch 100 generator loss : 0.962149
# batch 120 discriminator loss : 0.410334
# batch 120 generator loss : 0.881125
# batch 140 discriminator loss : 0.429972
# batch 140 generator loss : 0.870082
# batch 160 discriminator loss : 0.425004
# batch 160 generator loss : 0.921002
# batch 180 discriminator loss : 0.425668
# batch 180 generator loss : 0.933351
# batch 200 discriminator loss : 0.396514
# batch 200 generator loss : 0.955103
# batch 220 discriminator loss : 0.397208
# batch 220 generator loss : 0.987442
# batch 240 discriminator loss : 0.374723
# batch 240 generator loss : 1.026493
# batch 260 discriminator loss : 0.372625
# batch 260 generator loss : 1.033170
# batch 280 discriminator loss : 0.360108
# batch 280 generator loss : 1.046539
# batch 300 discriminator loss : 0.368138
# batch 300 generator loss : 1.043354
# batch 320 discriminator loss : 0.362045
# batch 320 generator loss : 1.025957
# batch 340 discriminator loss : 0.379767
# batch 340 generator loss : 1.022985
# batch 360 discriminator loss : 0.428976
# batch 360 generator loss : 1.001852
# batch 380 discriminator loss : 0.393476
# batch 380 generator loss : 0.946139
# batch 400 discriminator loss : 0.441055
# batch 400 generator loss : 0.918104
# batch 420 discriminator loss : 0.474241
# batch 420 generator loss : 0.932072
# batch 440 discriminator loss : 0.486238
# batch 440 generator loss : 0.894772
# batch 460 discriminator loss : 0.461635
# batch 460 generator loss : 0.908635
# Epoch is  19
# batch 0 discriminator loss : 0.488474
# batch 0 generator loss : 0.894099
# batch 20 discriminator loss : 0.486105
# batch 20 generator loss : 0.930409
# batch 40 discriminator loss : 0.478282
# batch 40 generator loss : 0.984254
# batch 60 discriminator loss : 0.472749
# batch 60 generator loss : 1.034842
# batch 80 discriminator loss : 0.467217
# batch 80 generator loss : 1.147207
# batch 100 discriminator loss : 0.482353
# batch 100 generator loss : 1.251360
# batch 120 discriminator loss : 0.454740
# batch 120 generator loss : 1.297446
# batch 140 discriminator loss : 0.440459
# batch 140 generator loss : 1.385968
# batch 160 discriminator loss : 0.417049
# batch 160 generator loss : 1.480035
# batch 180 discriminator loss : 0.413420
# batch 180 generator loss : 1.546664
# batch 200 discriminator loss : 0.416186
# batch 200 generator loss : 1.594528
# batch 220 discriminator loss : 0.393430
# batch 220 generator loss : 1.627134
# batch 240 discriminator loss : 0.381746
# batch 240 generator loss : 1.675970
# batch 260 discriminator loss : 0.371103
# batch 260 generator loss : 1.650722
# batch 280 discriminator loss : 0.377747
# batch 280 generator loss : 1.608654
# batch 300 discriminator loss : 0.323359
# batch 300 generator loss : 1.631951
# batch 320 discriminator loss : 0.307313
# batch 320 generator loss : 1.590058
# batch 340 discriminator loss : 0.297841
# batch 340 generator loss : 1.598300
# batch 360 discriminator loss : 0.299175
# batch 360 generator loss : 1.597553
# batch 380 discriminator loss : 0.266599
# batch 380 generator loss : 1.593137
# batch 400 discriminator loss : 0.255141
# batch 400 generator loss : 1.574201
# batch 420 discriminator loss : 0.279719
# batch 420 generator loss : 1.559512
# batch 440 discriminator loss : 0.263755
# batch 440 generator loss : 1.550809
# batch 460 discriminator loss : 0.269093
# batch 460 generator loss : 1.532141
# Epoch is  20
# batch 0 discriminator loss : 0.280260
# batch 0 generator loss : 1.515245
# batch 20 discriminator loss : 0.252996
# batch 20 generator loss : 1.475165
# batch 40 discriminator loss : 0.268088
# batch 40 generator loss : 1.429855
# batch 60 discriminator loss : 0.253811
# batch 60 generator loss : 1.380054
# batch 80 discriminator loss : 0.279866
# batch 80 generator loss : 1.308775
# batch 100 discriminator loss : 0.311088
# batch 100 generator loss : 1.261592
# batch 120 discriminator loss : 0.315721
# batch 120 generator loss : 1.201730
# batch 140 discriminator loss : 0.328485
# batch 140 generator loss : 1.122322
# batch 160 discriminator loss : 0.332073
# batch 160 generator loss : 1.067481
# batch 180 discriminator loss : 0.373331
# batch 180 generator loss : 0.991260
# batch 200 discriminator loss : 0.417739
# batch 200 generator loss : 0.974747
# batch 220 discriminator loss : 0.396718
# batch 220 generator loss : 0.905679
# batch 240 discriminator loss : 0.420510
# batch 240 generator loss : 0.917880
# batch 260 discriminator loss : 0.444424
# batch 260 generator loss : 0.901565
# batch 280 discriminator loss : 0.448277
# batch 280 generator loss : 0.912677
# batch 300 discriminator loss : 0.398193
# batch 300 generator loss : 0.947735
# batch 320 discriminator loss : 0.419392
# batch 320 generator loss : 0.959399
# batch 340 discriminator loss : 0.420103
# batch 340 generator loss : 1.012352
# batch 360 discriminator loss : 0.400315
# batch 360 generator loss : 1.049405
# batch 380 discriminator loss : 0.378483
# batch 380 generator loss : 1.105227
# batch 400 discriminator loss : 0.357307
# batch 400 generator loss : 1.171072
# batch 420 discriminator loss : 0.378317
# batch 420 generator loss : 1.259529
# batch 440 discriminator loss : 0.348854
# batch 440 generator loss : 1.301378
# batch 460 discriminator loss : 0.375629
# batch 460 generator loss : 1.337999
# Epoch is  21
# batch 0 discriminator loss : 0.392701
# batch 0 generator loss : 1.397592
# batch 20 discriminator loss : 0.365881
# batch 20 generator loss : 1.425181
# batch 40 discriminator loss : 0.385639
# batch 40 generator loss : 1.390787
# batch 60 discriminator loss : 0.395290
# batch 60 generator loss : 1.401303
# batch 80 discriminator loss : 0.368671
# batch 80 generator loss : 1.417767
# batch 100 discriminator loss : 0.451681
# batch 100 generator loss : 1.356245
# batch 120 discriminator loss : 0.503944
# batch 120 generator loss : 1.451881
# batch 140 discriminator loss : 0.502687
# batch 140 generator loss : 1.357066
# batch 160 discriminator loss : 0.480741
# batch 160 generator loss : 1.479983
# batch 180 discriminator loss : 0.491393
# batch 180 generator loss : 1.541150
# batch 200 discriminator loss : 0.565805
# batch 200 generator loss : 1.480107
# batch 220 discriminator loss : 0.535376
# batch 220 generator loss : 1.490967
# batch 240 discriminator loss : 0.622979
# batch 240 generator loss : 1.556207
# batch 260 discriminator loss : 0.636065
# batch 260 generator loss : 1.648961
# batch 280 discriminator loss : 0.683802
# batch 280 generator loss : 1.605775
# batch 300 discriminator loss : 0.595663
# batch 300 generator loss : 1.604164
# batch 320 discriminator loss : 0.587598
# batch 320 generator loss : 1.733202
# batch 340 discriminator loss : 0.569954
# batch 340 generator loss : 1.722357
# batch 360 discriminator loss : 0.573680
# batch 360 generator loss : 1.752290
# batch 380 discriminator loss : 0.463234
# batch 380 generator loss : 1.752136
# batch 400 discriminator loss : 0.430762
# batch 400 generator loss : 1.754298
# batch 420 discriminator loss : 0.468592
# batch 420 generator loss : 1.698941
# batch 440 discriminator loss : 0.419503
# batch 440 generator loss : 1.671143
# batch 460 discriminator loss : 0.409578
# batch 460 generator loss : 1.651876
# Epoch is  22
# batch 0 discriminator loss : 0.393921
# batch 0 generator loss : 1.537450
# batch 20 discriminator loss : 0.374527
# batch 20 generator loss : 1.551430
# batch 40 discriminator loss : 0.388291
# batch 40 generator loss : 1.541220
# batch 60 discriminator loss : 0.408201
# batch 60 generator loss : 1.473536
# batch 80 discriminator loss : 0.415356
# batch 80 generator loss : 1.379119
# batch 100 discriminator loss : 0.451181
# batch 100 generator loss : 1.299666
# batch 120 discriminator loss : 0.436552
# batch 120 generator loss : 1.200189
# batch 140 discriminator loss : 0.457261
# batch 140 generator loss : 1.147185
# batch 160 discriminator loss : 0.460593
# batch 160 generator loss : 1.056078
# batch 180 discriminator loss : 0.553816
# batch 180 generator loss : 0.965274
# batch 200 discriminator loss : 0.561197
# batch 200 generator loss : 0.950756
# batch 220 discriminator loss : 0.591068
# batch 220 generator loss : 0.913566
# batch 240 discriminator loss : 0.557610
# batch 240 generator loss : 0.964020
# batch 260 discriminator loss : 0.579167
# batch 260 generator loss : 1.020334
# batch 280 discriminator loss : 0.567272
# batch 280 generator loss : 1.126863
# batch 300 discriminator loss : 0.480570
# batch 300 generator loss : 1.244613
# batch 320 discriminator loss : 0.439448
# batch 320 generator loss : 1.397424
# batch 340 discriminator loss : 0.407867
# batch 340 generator loss : 1.599599
# batch 360 discriminator loss : 0.347931
# batch 360 generator loss : 1.843023
# batch 380 discriminator loss : 0.280986
# batch 380 generator loss : 2.038464
# batch 400 discriminator loss : 0.260126
# batch 400 generator loss : 2.196146
# batch 420 discriminator loss : 0.241507
# batch 420 generator loss : 2.236829
# batch 440 discriminator loss : 0.225593
# batch 440 generator loss : 2.271297
# batch 460 discriminator loss : 0.209366
# batch 460 generator loss : 2.239880
# Epoch is  23
# batch 0 discriminator loss : 0.226595
# batch 0 generator loss : 2.171440
# batch 20 discriminator loss : 0.233549
# batch 20 generator loss : 2.095810
# batch 40 discriminator loss : 0.259267
# batch 40 generator loss : 1.921709
# batch 60 discriminator loss : 0.314512
# batch 60 generator loss : 1.765037
# batch 80 discriminator loss : 0.353994
# batch 80 generator loss : 1.658853
# batch 100 discriminator loss : 0.400701
# batch 100 generator loss : 1.441686
# batch 120 discriminator loss : 0.384041
# batch 120 generator loss : 1.230980
# batch 140 discriminator loss : 0.444292
# batch 140 generator loss : 1.084177
# batch 160 discriminator loss : 0.500170
# batch 160 generator loss : 1.087925
# batch 180 discriminator loss : 0.479720
# batch 180 generator loss : 1.126083
# batch 200 discriminator loss : 0.511341
# batch 200 generator loss : 1.233339
# batch 220 discriminator loss : 0.476176
# batch 220 generator loss : 1.559300
# batch 240 discriminator loss : 0.467651
# batch 240 generator loss : 1.665507
# batch 260 discriminator loss : 0.448604
# batch 260 generator loss : 1.933674
# batch 280 discriminator loss : 0.456484
# batch 280 generator loss : 2.135392
# batch 300 discriminator loss : 0.421024
# batch 300 generator loss : 2.389691
# batch 320 discriminator loss : 0.431969
# batch 320 generator loss : 2.577868
# batch 340 discriminator loss : 0.387672
# batch 340 generator loss : 2.657982
# batch 360 discriminator loss : 0.365869
# batch 360 generator loss : 2.812171
# batch 380 discriminator loss : 0.324068
# batch 380 generator loss : 2.776502
# batch 400 discriminator loss : 0.325466
# batch 400 generator loss : 2.653378
# batch 420 discriminator loss : 0.249362
# batch 420 generator loss : 2.540357
# batch 440 discriminator loss : 0.233020
# batch 440 generator loss : 2.519568
# batch 460 discriminator loss : 0.215333
# batch 460 generator loss : 2.455661
# Epoch is  24
# batch 0 discriminator loss : 0.212668
# batch 0 generator loss : 2.260561
# batch 20 discriminator loss : 0.194945
# batch 20 generator loss : 2.207015
# batch 40 discriminator loss : 0.213739
# batch 40 generator loss : 2.010321
# batch 60 discriminator loss : 0.218206
# batch 60 generator loss : 1.715443
# batch 80 discriminator loss : 0.294137
# batch 80 generator loss : 1.588137
# batch 100 discriminator loss : 0.258126
# batch 100 generator loss : 1.346389
# batch 120 discriminator loss : 0.315308
# batch 120 generator loss : 1.228140
# batch 140 discriminator loss : 0.341399
# batch 140 generator loss : 1.086849
# batch 160 discriminator loss : 0.397571
# batch 160 generator loss : 0.933750
# batch 180 discriminator loss : 0.499263
# batch 180 generator loss : 0.751143
# batch 200 discriminator loss : 0.519951
# batch 200 generator loss : 0.671693
# batch 220 discriminator loss : 0.582775
# batch 220 generator loss : 0.639319
# batch 240 discriminator loss : 0.585810
# batch 240 generator loss : 0.586776
# batch 260 discriminator loss : 0.603249
# batch 260 generator loss : 0.624666
# batch 280 discriminator loss : 0.604414
# batch 280 generator loss : 0.724704
# batch 300 discriminator loss : 0.572882
# batch 300 generator loss : 0.800866
# batch 320 discriminator loss : 0.515798
# batch 320 generator loss : 0.985864
# batch 340 discriminator loss : 0.436162
# batch 340 generator loss : 1.190002
# batch 360 discriminator loss : 0.362047
# batch 360 generator loss : 1.387292
# batch 380 discriminator loss : 0.291775
# batch 380 generator loss : 1.606675
# batch 400 discriminator loss : 0.266612
# batch 400 generator loss : 1.846507
# batch 420 discriminator loss : 0.216973
# batch 420 generator loss : 2.074942
# batch 440 discriminator loss : 0.193939
# batch 440 generator loss : 2.157117
# batch 460 discriminator loss : 0.172342
# batch 460 generator loss : 2.110345
# Epoch is  25
# batch 0 discriminator loss : 0.177639
# batch 0 generator loss : 2.074139
# batch 20 discriminator loss : 0.172499
# batch 20 generator loss : 1.998280
# batch 40 discriminator loss : 0.200983
# batch 40 generator loss : 1.809682
# batch 60 discriminator loss : 0.249317
# batch 60 generator loss : 1.626923
# batch 80 discriminator loss : 0.292249
# batch 80 generator loss : 1.495164
# batch 100 discriminator loss : 0.355380
# batch 100 generator loss : 1.298238
# batch 120 discriminator loss : 0.393328
# batch 120 generator loss : 1.215924
# batch 140 discriminator loss : 0.467740
# batch 140 generator loss : 1.158912
# batch 160 discriminator loss : 0.465532
# batch 160 generator loss : 1.035729
# batch 180 discriminator loss : 0.534396
# batch 180 generator loss : 1.074538
# batch 200 discriminator loss : 0.481900
# batch 200 generator loss : 1.144270
# batch 220 discriminator loss : 0.481994
# batch 220 generator loss : 1.397939
# batch 240 discriminator loss : 0.469959
# batch 240 generator loss : 1.637722
# batch 260 discriminator loss : 0.474458
# batch 260 generator loss : 1.866938
# batch 280 discriminator loss : 0.500524
# batch 280 generator loss : 2.115277
# batch 300 discriminator loss : 0.446076
# batch 300 generator loss : 2.348746
# batch 320 discriminator loss : 0.438501
# batch 320 generator loss : 2.485302
# batch 340 discriminator loss : 0.421691
# batch 340 generator loss : 2.583645
# batch 360 discriminator loss : 0.386061
# batch 360 generator loss : 2.504903
# batch 380 discriminator loss : 0.329102
# batch 380 generator loss : 2.540525
# batch 400 discriminator loss : 0.295817
# batch 400 generator loss : 2.416900
# batch 420 discriminator loss : 0.275229
# batch 420 generator loss : 2.302726
# batch 440 discriminator loss : 0.222427
# batch 440 generator loss : 2.199321
# batch 460 discriminator loss : 0.217525
# batch 460 generator loss : 2.081732
# Epoch is  26
# batch 0 discriminator loss : 0.224691
# batch 0 generator loss : 1.946479
# batch 20 discriminator loss : 0.200125
# batch 20 generator loss : 1.872550
# batch 40 discriminator loss : 0.219907
# batch 40 generator loss : 1.779878
# batch 60 discriminator loss : 0.228618
# batch 60 generator loss : 1.678460
# batch 80 discriminator loss : 0.273568
# batch 80 generator loss : 1.538078
# batch 100 discriminator loss : 0.289092
# batch 100 generator loss : 1.475708
# batch 120 discriminator loss : 0.304234
# batch 120 generator loss : 1.372829
# ...
# batch 120 discriminator loss : 0.053512
# batch 120 generator loss : 3.230497
# batch 140 discriminator loss : 0.038857
# batch 140 generator loss : 3.368915
# batch 160 discriminator loss : 0.048286
# batch 160 generator loss : 3.470981
# batch 180 discriminator loss : 0.047705
# batch 180 generator loss : 3.543167
# batch 200 discriminator loss : 0.047347
# batch 200 generator loss : 3.502541
# batch 220 discriminator loss : 0.042423
# batch 220 generator loss : 3.499648
# batch 240 discriminator loss : 0.049340
# batch 240 generator loss : 3.458808
# batch 260 discriminator loss : 0.047791
# batch 260 generator loss : 3.421447
# batch 280 discriminator loss : 0.056312
# batch 280 generator loss : 3.253430
# batch 300 discriminator loss : 0.045668
# batch 300 generator loss : 3.221837
# batch 320 discriminator loss : 0.049591
# batch 320 generator loss : 3.253101
# batch 340 discriminator loss : 0.044935
# batch 340 generator loss : 3.367734
# batch 360 discriminator loss : 0.047507
# batch 360 generator loss : 3.361936
# batch 380 discriminator loss : 0.044522
# batch 380 generator loss : 3.413158
# batch 400 discriminator loss : 0.043050
# batch 400 generator loss : 3.483231
# batch 420 discriminator loss : 0.050543
# batch 420 generator loss : 3.494103
# batch 440 discriminator loss : 0.039891
# batch 440 generator loss : 3.511139
# batch 460 discriminator loss : 0.034808
# batch 460 generator loss : 3.612918
# Epoch is  92
# batch 0 discriminator loss : 0.048980
# batch 0 generator loss : 3.562035
# batch 20 discriminator loss : 0.041624
# batch 20 generator loss : 3.537487
# batch 40 discriminator loss : 0.043936
# batch 40 generator loss : 3.522866
# batch 60 discriminator loss : 0.051423
# batch 60 generator loss : 3.414232
# batch 80 discriminator loss : 0.048229
# batch 80 generator loss : 3.334738
# batch 100 discriminator loss : 0.049020
# batch 100 generator loss : 3.182660
# batch 120 discriminator loss : 0.053626
# batch 120 generator loss : 3.247044
# batch 140 discriminator loss : 0.038283
# batch 140 generator loss : 3.384144
# batch 160 discriminator loss : 0.041766
# batch 160 generator loss : 3.439310
# batch 180 discriminator loss : 0.045627
# batch 180 generator loss : 3.458808
# batch 200 discriminator loss : 0.047270
# batch 200 generator loss : 3.424535
# batch 220 discriminator loss : 0.040215
# batch 220 generator loss : 3.463221
# batch 240 discriminator loss : 0.048138
# batch 240 generator loss : 3.429660
# batch 260 discriminator loss : 0.048566
# batch 260 generator loss : 3.344414
# batch 280 discriminator loss : 0.058549
# batch 280 generator loss : 3.295293
# batch 300 discriminator loss : 0.047016
# batch 300 generator loss : 3.404044
# batch 320 discriminator loss : 0.050753
# batch 320 generator loss : 3.296549
# batch 340 discriminator loss : 0.041829
# batch 340 generator loss : 3.437822
# batch 360 discriminator loss : 0.051352
# batch 360 generator loss : 3.482591
# batch 380 discriminator loss : 0.044888
# batch 380 generator loss : 3.452897
# batch 400 discriminator loss : 0.044225
# batch 400 generator loss : 3.416708
# batch 420 discriminator loss : 0.049125
# batch 420 generator loss : 3.467869
# batch 440 discriminator loss : 0.040475
# batch 440 generator loss : 3.440097
# batch 460 discriminator loss : 0.035081
# batch 460 generator loss : 3.558852
# Epoch is  93
# batch 0 discriminator loss : 0.046784
# batch 0 generator loss : 3.543307
# batch 20 discriminator loss : 0.041581
# batch 20 generator loss : 3.566290
# batch 40 discriminator loss : 0.045761
# batch 40 generator loss : 3.495926
# batch 60 discriminator loss : 0.048991
# batch 60 generator loss : 3.296818
# batch 80 discriminator loss : 0.048177
# batch 80 generator loss : 3.381200
# batch 100 discriminator loss : 0.051375
# batch 100 generator loss : 3.370111
# batch 120 discriminator loss : 0.053527
# batch 120 generator loss : 3.244543
# batch 140 discriminator loss : 0.041161
# batch 140 generator loss : 3.405535
# batch 160 discriminator loss : 0.042916
# batch 160 generator loss : 3.496274
# batch 180 discriminator loss : 0.047827
# batch 180 generator loss : 3.522073
# batch 200 discriminator loss : 0.046268
# batch 200 generator loss : 3.526182
# batch 220 discriminator loss : 0.042313
# batch 220 generator loss : 3.433205
# batch 240 discriminator loss : 0.049086
# batch 240 generator loss : 3.498358
# batch 260 discriminator loss : 0.049516
# batch 260 generator loss : 3.404635
# batch 280 discriminator loss : 0.058013
# batch 280 generator loss : 3.361739
# batch 300 discriminator loss : 0.046768
# batch 300 generator loss : 3.363403
# batch 320 discriminator loss : 0.047399
# batch 320 generator loss : 3.278126
# batch 340 discriminator loss : 0.041998
# batch 340 generator loss : 3.351686
# batch 360 discriminator loss : 0.049333
# batch 360 generator loss : 3.371878
# batch 380 discriminator loss : 0.044083
# batch 380 generator loss : 3.497132
# batch 400 discriminator loss : 0.043894
# batch 400 generator loss : 3.561893
# batch 420 discriminator loss : 0.048895
# batch 420 generator loss : 3.527162
# batch 440 discriminator loss : 0.037563
# batch 440 generator loss : 3.508679
# batch 460 discriminator loss : 0.035031
# batch 460 generator loss : 3.513858
# Epoch is  94
# batch 0 discriminator loss : 0.050799
# batch 0 generator loss : 3.636784
# batch 20 discriminator loss : 0.041492
# batch 20 generator loss : 3.522497
# batch 40 discriminator loss : 0.043637
# batch 40 generator loss : 3.490897
# batch 60 discriminator loss : 0.050645
# batch 60 generator loss : 3.325880
# batch 80 discriminator loss : 0.047873
# batch 80 generator loss : 3.322168
# batch 100 discriminator loss : 0.051497
# batch 100 generator loss : 3.373603
# batch 120 discriminator loss : 0.053175
# batch 120 generator loss : 3.234711
# batch 140 discriminator loss : 0.038263
# batch 140 generator loss : 3.387215
# batch 160 discriminator loss : 0.040821
# batch 160 generator loss : 3.419977
# batch 180 discriminator loss : 0.048858
# batch 180 generator loss : 3.544970
# batch 200 discriminator loss : 0.045537
# batch 200 generator loss : 3.497551
# batch 220 discriminator loss : 0.039688
# batch 220 generator loss : 3.633499
# batch 240 discriminator loss : 0.049144
# batch 240 generator loss : 3.357112
# batch 260 discriminator loss : 0.047111
# batch 260 generator loss : 3.470365
# batch 280 discriminator loss : 0.057495
# batch 280 generator loss : 3.245010
# batch 300 discriminator loss : 0.047723
# batch 300 generator loss : 3.244272
# batch 320 discriminator loss : 0.050977
# batch 320 generator loss : 3.327310
# batch 340 discriminator loss : 0.042899
# batch 340 generator loss : 3.584754
# batch 360 discriminator loss : 0.051142
# batch 360 generator loss : 3.468452
# batch 380 discriminator loss : 0.041233
# batch 380 generator loss : 3.509143
# batch 400 discriminator loss : 0.043503
# batch 400 generator loss : 3.531225
# batch 420 discriminator loss : 0.045647
# batch 420 generator loss : 3.398112
# batch 440 discriminator loss : 0.037516
# batch 440 generator loss : 3.570632
# batch 460 discriminator loss : 0.035709
# batch 460 generator loss : 3.676229
# Epoch is  95
# batch 0 discriminator loss : 0.043394
# batch 0 generator loss : 3.653184
# batch 20 discriminator loss : 0.039298
# batch 20 generator loss : 3.599994
# batch 40 discriminator loss : 0.042806
# batch 40 generator loss : 3.579047
# batch 60 discriminator loss : 0.046624
# batch 60 generator loss : 3.403799
# batch 80 discriminator loss : 0.045669
# batch 80 generator loss : 3.280819
# batch 100 discriminator loss : 0.049571
# batch 100 generator loss : 3.315461
# batch 120 discriminator loss : 0.051080
# batch 120 generator loss : 3.308334
# batch 140 discriminator loss : 0.038812
# batch 140 generator loss : 3.489543
# batch 160 discriminator loss : 0.041356
# batch 160 generator loss : 3.531659
# batch 180 discriminator loss : 0.048548
# batch 180 generator loss : 3.557867
# batch 200 discriminator loss : 0.044315
# batch 200 generator loss : 3.578512
# batch 220 discriminator loss : 0.040549
# batch 220 generator loss : 3.584559
# batch 240 discriminator loss : 0.044759
# batch 240 generator loss : 3.591084
# batch 260 discriminator loss : 0.047177
# batch 260 generator loss : 3.440963
# batch 280 discriminator loss : 0.054988
# batch 280 generator loss : 3.341017
# batch 300 discriminator loss : 0.044636
# batch 300 generator loss : 3.305246
# batch 320 discriminator loss : 0.045686
# batch 320 generator loss : 3.392411
# batch 340 discriminator loss : 0.040215
# batch 340 generator loss : 3.406806
# batch 360 discriminator loss : 0.045722
# batch 360 generator loss : 3.401567
# batch 380 discriminator loss : 0.041582
# batch 380 generator loss : 3.532622
# batch 400 discriminator loss : 0.041298
# batch 400 generator loss : 3.564274
# batch 420 discriminator loss : 0.045491
# batch 420 generator loss : 3.536201
# batch 440 discriminator loss : 0.036127
# batch 440 generator loss : 3.675593
# batch 460 discriminator loss : 0.036155
# batch 460 generator loss : 3.677778
# Epoch is  96
# batch 0 discriminator loss : 0.041691
# batch 0 generator loss : 3.685017
# batch 20 discriminator loss : 0.040768
# batch 20 generator loss : 3.680076
# batch 40 discriminator loss : 0.040915
# batch 40 generator loss : 3.686220
# batch 60 discriminator loss : 0.048432
# batch 60 generator loss : 3.451818
# batch 80 discriminator loss : 0.044946
# batch 80 generator loss : 3.386945
# batch 100 discriminator loss : 0.047837
# batch 100 generator loss : 3.404830
# batch 120 discriminator loss : 0.051627
# batch 120 generator loss : 3.470983
# batch 140 discriminator loss : 0.034094
# batch 140 generator loss : 3.461006
# batch 160 discriminator loss : 0.038193
# batch 160 generator loss : 3.630641
# batch 180 discriminator loss : 0.043718
# batch 180 generator loss : 3.563231
# batch 200 discriminator loss : 0.041157
# batch 200 generator loss : 3.494789
# batch 220 discriminator loss : 0.036524
# batch 220 generator loss : 3.677669
# batch 240 discriminator loss : 0.042689
# batch 240 generator loss : 3.659503
# batch 260 discriminator loss : 0.044550
# batch 260 generator loss : 3.539416
# batch 280 discriminator loss : 0.051938
# batch 280 generator loss : 3.432556
# batch 300 discriminator loss : 0.042750
# batch 300 generator loss : 3.384222
# batch 320 discriminator loss : 0.043278
# batch 320 generator loss : 3.391022
# batch 340 discriminator loss : 0.039451
# batch 340 generator loss : 3.581994
# batch 360 discriminator loss : 0.046631
# batch 360 generator loss : 3.582617
# batch 380 discriminator loss : 0.040107
# batch 380 generator loss : 3.617595
# batch 400 discriminator loss : 0.041180
# batch 400 generator loss : 3.558521
# batch 420 discriminator loss : 0.044650
# batch 420 generator loss : 3.619344
# batch 440 discriminator loss : 0.036885
# batch 440 generator loss : 3.571889
# batch 460 discriminator loss : 0.033736
# batch 460 generator loss : 3.747919
# Epoch is  97
# batch 0 discriminator loss : 0.041493
# batch 0 generator loss : 3.749473
# batch 20 discriminator loss : 0.037569
# batch 20 generator loss : 3.695841
# batch 40 discriminator loss : 0.040289
# batch 40 generator loss : 3.613109
# batch 60 discriminator loss : 0.045740
# batch 60 generator loss : 3.393401
# batch 80 discriminator loss : 0.042094
# batch 80 generator loss : 3.236407
# batch 100 discriminator loss : 0.044939
# batch 100 generator loss : 3.273225
# batch 120 discriminator loss : 0.048280
# batch 120 generator loss : 3.437146
# batch 140 discriminator loss : 0.035354
# batch 140 generator loss : 3.354167
# batch 160 discriminator loss : 0.038880
# batch 160 generator loss : 3.503066
# batch 180 discriminator loss : 0.043716
# batch 180 generator loss : 3.628299
# batch 200 discriminator loss : 0.041643
# batch 200 generator loss : 3.659986
# batch 220 discriminator loss : 0.038064
# batch 220 generator loss : 3.746503
# batch 240 discriminator loss : 0.043876
# batch 240 generator loss : 3.546119
# batch 260 discriminator loss : 0.043770
# batch 260 generator loss : 3.534613
# batch 280 discriminator loss : 0.051683
# batch 280 generator loss : 3.423023
# batch 300 discriminator loss : 0.038744
# batch 300 generator loss : 3.356327
# batch 320 discriminator loss : 0.045158
# batch 320 generator loss : 3.427675
# batch 340 discriminator loss : 0.038869
# batch 340 generator loss : 3.461788
# batch 360 discriminator loss : 0.043469
# batch 360 generator loss : 3.508644
# batch 380 discriminator loss : 0.039488
# batch 380 generator loss : 3.654923
# batch 400 discriminator loss : 0.039736
# batch 400 generator loss : 3.640667
# batch 420 discriminator loss : 0.041707
# batch 420 generator loss : 3.567425
# batch 440 discriminator loss : 0.034489
# batch 440 generator loss : 3.603481
# batch 460 discriminator loss : 0.031198
# batch 460 generator loss : 3.659995
# Epoch is  98
# batch 0 discriminator loss : 0.038521
# batch 0 generator loss : 3.756313
# batch 20 discriminator loss : 0.039331
# batch 20 generator loss : 3.750429
# batch 40 discriminator loss : 0.038157
# batch 40 generator loss : 3.677913
# batch 60 discriminator loss : 0.042700
# batch 60 generator loss : 3.533010
# batch 80 discriminator loss : 0.041082
# batch 80 generator loss : 3.343626
# batch 100 discriminator loss : 0.042040
# batch 100 generator loss : 3.488728
# batch 120 discriminator loss : 0.044070
# batch 120 generator loss : 3.425149
# batch 140 discriminator loss : 0.036611
# batch 140 generator loss : 3.421505
# batch 160 discriminator loss : 0.040078
# batch 160 generator loss : 3.553831
# batch 180 discriminator loss : 0.041973
# batch 180 generator loss : 3.586192
# batch 200 discriminator loss : 0.037154
# batch 200 generator loss : 3.565056
# batch 220 discriminator loss : 0.033856
# batch 220 generator loss : 3.708242
# batch 240 discriminator loss : 0.040564
# batch 240 generator loss : 3.706679
# batch 260 discriminator loss : 0.039340
# batch 260 generator loss : 3.622306
# batch 280 discriminator loss : 0.047020
# batch 280 generator loss : 3.504638
# batch 300 discriminator loss : 0.039045
# batch 300 generator loss : 3.422264
# batch 320 discriminator loss : 0.042382
# batch 320 generator loss : 3.445664
# batch 340 discriminator loss : 0.036699
# batch 340 generator loss : 3.627190
# batch 360 discriminator loss : 0.043374
# batch 360 generator loss : 3.680008
# batch 380 discriminator loss : 0.037305
# batch 380 generator loss : 3.651971
# batch 400 discriminator loss : 0.037034
# batch 400 generator loss : 3.695833
# batch 420 discriminator loss : 0.040632
# batch 420 generator loss : 3.595273
# batch 440 discriminator loss : 0.033884
# batch 440 generator loss : 3.635350
# batch 460 discriminator loss : 0.030951
# batch 460 generator loss : 3.729004
# Epoch is  99
# batch 0 discriminator loss : 0.036550
# batch 0 generator loss : 3.689802
# batch 20 discriminator loss : 0.032426
# batch 20 generator loss : 3.868369
# batch 40 discriminator loss : 0.035905
# batch 40 generator loss : 3.731879
# batch 60 discriminator loss : 0.041663
# batch 60 generator loss : 3.559436
# batch 80 discriminator loss : 0.039112
# batch 80 generator loss : 3.517646
# batch 100 discriminator loss : 0.040598
# batch 100 generator loss : 3.409715
# batch 120 discriminator loss : 0.043294
# batch 120 generator loss : 3.375289
# batch 140 discriminator loss : 0.039702
# batch 140 generator loss : 3.502820
# batch 160 discriminator loss : 0.036639
# batch 160 generator loss : 3.659950
# batch 180 discriminator loss : 0.040396
# batch 180 generator loss : 3.690283
# batch 200 discriminator loss : 0.036486
# batch 200 generator loss : 3.677533
# batch 220 discriminator loss : 0.033012
# batch 220 generator loss : 3.685214
# batch 240 discriminator loss : 0.038770
# batch 240 generator loss : 3.615193
# batch 260 discriminator loss : 0.037894
# batch 260 generator loss : 3.556347
# batch 280 discriminator loss : 0.047074
# batch 280 generator loss : 3.445549
# batch 300 discriminator loss : 0.038318
# batch 300 generator loss : 3.430426
# batch 320 discriminator loss : 0.042755
# batch 320 generator loss : 3.416966
# batch 340 discriminator loss : 0.037303
# batch 340 generator loss : 3.545087
# batch 360 discriminator loss : 0.040911
# batch 360 generator loss : 3.653052
# batch 380 discriminator loss : 0.034894
# batch 380 generator loss : 3.701997
# batch 400 discriminator loss : 0.038387
# batch 400 generator loss : 3.691180
# batch 420 discriminator loss : 0.041422
# batch 420 generator loss : 3.646744
# batch 440 discriminator loss : 0.031698
# batch 440 generator loss : 3.601321
# batch 460 discriminator loss : 0.030924
# batch 460 generator loss : 3.723573

# %%
model1.save_weights("generator",True)
model2.save_weights("discriminator",True)

# %% [markdown]
# # Generation

# %%
model1.compile(loss='binary_crossentropy',optimizer="SGD")
model1.load_weights('generator')
noise = numpy.random.uniform(-1,1,(batch_size,100))
g_iamges2 = model1.predict(noise,verbose=1)
img = combine_images(g_iamges2)
img = img*127.5 + 127.5
Image.fromarray(img.astype(numpy.uint8)[:28,:28]).save("generated_image.png")
# Out:
# 128/128 [==============================] - 0s 656us/step

# %%
img = cv2.imread("generated_image.png")
img.shape
# Out:
# (28, 28, 3)

# %%
plt.imshow(img)
plt.show()
